# %% [markdown]
# Instalando requisitos

# %%
# %pip install -r requirements.txt
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Importando requisitos

# %%
from app.modelo.imagem_tons_cinza import ImagemTonsCinza
import matplotlib.pyplot as plt
from PIL import Image
import io

# %% [markdown]
# Abrindo imagem

# %%
imagem_tons_cinza = ImagemTonsCinza.from_file('ex.png')

# %%
imagem_tons_cinza.to_image()
# Out:
# <PIL.Image.Image image mode=L size=651x323>

# %%
histograma_tons_cinza = imagem_tons_cinza.to_histograma()

# %%
list(histograma_tons_cinza)
# Out:
# [240, 224, 208, 176, 144, 128, 64, 112, 192, 160, 96, 80, 16, 32, 48, 0]

# %%
dado = list(histograma_tons_cinza.items())

# %%
dado.sort(key=lambda x: x[0])

# %%
dado
# Out:
# [(0, 462),
#  (16, 133),
#  (32, 246),
#  (48, 1351),
#  (64, 4554),
#  (80, 2486),
#  (96, 816),
#  (112, 1126),
#  (128, 789),
#  (144, 929),
#  (160, 831),
#  (176, 1185),
#  (192, 3766),
#  (208, 2343),
#  (224, 39991),
#  (240, 149265)]

# %%
# x = []
# y = []
# for k, v in dado:
#     x.append(k)
#     y.append(v)

# %%
x, y = zip(*dado)

# %%
x
# Out:
# (0, 16, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240)

# %%
y
# Out:
# (462,
#  133,
#  246,
#  1351,
#  4554,
#  2486,
#  816,
#  1126,
#  789,
#  929,
#  831,
#  1185,
#  3766,
#  2343,
#  39991,
#  149265)

# %%
def buffer_plot_and_get(fig):
    buf = io.BytesIO()
    fig.savefig(buf)
    buf.seek(0)
    return Image.open(buf)

# %%
fig, ax = plt.subplots()
ax.bar(x, y, width=15.0)
_ = buffer_plot_and_get(fig)
""
# Out:
# ''
