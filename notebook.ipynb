# %% [markdown]
# # Trabalho Prático

# %% [markdown]
# # 1ª etapa

# %% [markdown]
# Recortando as imagens

# %%
# !pip install pandas
# !pip install numpy
# !pip install Pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/henrique/.local/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/henrique/.local/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/henrique/.local/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3.9/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.22.4 in /home/henrique/.local/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /home/henrique/.local/lib/python3.9/site-packages
# sysconfig: /home/henrique/.local/lib64/python3.9/site-packages
# WARNING: Additional context:
# user = True
# home = None
# root = None
# prefix = None
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/henrique/.local/lib/python3.9/site-packages (1.26.4)
# WARNING: Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /home/henrique/.local/lib/python3.9/site-packages
# sysconfig: /home/henrique/.local/lib64/python3.9/site-packages
# WARNING: Additional context:
# user = True
# home = None
# root = None
# prefix = None
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Pillow in /home/henrique/.local/lib/python3.9/site-packages (10.3.0)
# WARNING: Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /home/henrique/.local/lib/python3.9/site-packages
# sysconfig: /home/henrique/.local/lib64/python3.9/site-packages
# WARNING: Additional context:
# user = True
# home = None
# root = None
# prefix = None

# %%
import pandas
import os
import PIL.Image

# %%
data_frame = pandas.read_csv("classifications.csv")

# %%
data_frame
# Out:
#        image_id                        image_filename  \
# 0           400  9ae8a4edde40219bad6303cebc672ee4.png
# 1           400  9ae8a4edde40219bad6303cebc672ee4.png
# 2           400  9ae8a4edde40219bad6303cebc672ee4.png
# 3           400  9ae8a4edde40219bad6303cebc672ee4.png
# 4           400  9ae8a4edde40219bad6303cebc672ee4.png
# ...         ...                                   ...
# 11529         1  be340ee72689dfe3f8dc9c24de6127f4.png
# 11530         1  be340ee72689dfe3f8dc9c24de6127f4.png
# 11531         1  be340ee72689dfe3f8dc9c24de6127f4.png
# 11532         1  be340ee72689dfe3f8dc9c24de6127f4.png
# 11533         1  be340ee72689dfe3f8dc9c24de6127f4.png
#
#                           image_doi  cell_id  \
# 0      10.6084/m9.figshare.12230906        1
# 1      10.6084/m9.figshare.12230906        2
# 2      10.6084/m9.figshare.12230906        3
# 3      10.6084/m9.figshare.12230906        4
# 4      10.6084/m9.figshare.12230906        5
# ...                             ...      ...
# 11529  10.6084/m9.figshare.12229511    11530
# 11530  10.6084/m9.figshare.12229511    11531
# 11531  10.6084/m9.figshare.12229511    11532
# 11532  10.6084/m9.figshare.12229511    11533
# 11533  10.6084/m9.figshare.12229511    11534
#
#                            bethesda_system  nucleus_x  nucleus_y
# 0                                      SCC        792        462
# 1                                      SCC        601        678
# 2                                      SCC        363        467
# 3                                      SCC        599        437
# 4      Negative for intraepithelial lesion       1186        450
# ...                                    ...        ...        ...
# 11529                                 LSIL        618        407
# 11530                                 LSIL        607        374
# 11531                                 LSIL        707        251
# 11532                                 LSIL        579        246
# 11533  Negative for intraepithelial lesion        227        130
#
# [11534 rows x 7 columns]

# %%
data_set_dir = os.path.join(os.getcwd(), "dataset")

# %%
destination_image_dir = os.path.join(os.getcwd(), "dataset_converted")

# %%
if not os.path.exists(destination_image_dir):
    os.mkdir(destination_image_dir)

# %%
for index, row in data_frame.iterrows():

    source_image_path = os.path.join(data_set_dir, row['image_filename'])

    classe = row['bethesda_system']
    diretorio_classe = os.path.join(destination_image_dir, classe)
    if not os.path.exists(diretorio_classe):
        os.mkdir(diretorio_classe)
    
    destination_image_path = os.path.join(diretorio_classe, "{}.png".format(row['cell_id']))
    
    if os.path.exists(source_image_path):
        with PIL.Image.open(source_image_path) as image:
            esquerda = row['nucleus_x'] - 50
            direita = row['nucleus_x'] + 50
            inferior = row['nucleus_y'] - 50
            superior = row['nucleus_y'] + 50
            cropped_image = image.crop((esquerda, inferior, direita, superior))
            cropped_image.save(destination_image_path)
